# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Задание" data-toc-modified-id="Задание-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Задание</a></span></li><li><span><a href="#Запросы" data-toc-modified-id="Запросы-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Запросы</a></span><ul class="toc-item"><li><span><a href="#Посчитать,-сколько-компаний-закрылось." data-toc-modified-id="Посчитать,-сколько-компаний-закрылось.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посчитать, сколько компаний закрылось.</a></span></li><li><span><a href="#Отобразить-количество-привлечённых-средств-для-новостных-компаний-США.-Отсортировать-таблицу-по-убыванию-значений-в-поле-funding_total." data-toc-modified-id="Отобразить-количество-привлечённых-средств-для-новостных-компаний-США.-Отсортировать-таблицу-по-убыванию-значений-в-поле-funding_total.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Отобразить количество привлечённых средств для новостных компаний США. Отсортировать таблицу по убыванию значений в поле funding_total.</a></span></li><li><span><a href="#Найти-общую-сумму-сделок-по-покупке-одних-компаний-другими-в-долларах.-Отобрать-сделки,-которые-осуществлялись-только-за-наличные-с-2011-по-2013-год-включительно." data-toc-modified-id="Найти-общую-сумму-сделок-по-покупке-одних-компаний-другими-в-долларах.-Отобрать-сделки,-которые-осуществлялись-только-за-наличные-с-2011-по-2013-год-включительно.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Найти общую сумму сделок по покупке одних компаний другими в долларах. Отобрать сделки, которые осуществлялись только за наличные с 2011 по 2013 год включительно.</a></span></li><li><span><a href="#Отобразить-имя,-фамилию-и-названия-аккаунтов-людей-в-твиттере,-у-которых-названия-аккаунтов-начинаются-на-'Silver'." data-toc-modified-id="Отобразить-имя,-фамилию-и-названия-аккаунтов-людей-в-твиттере,-у-которых-названия-аккаунтов-начинаются-на-'Silver'.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Отобразить имя, фамилию и названия аккаунтов людей в твиттере, у которых названия аккаунтов начинаются на 'Silver'.</a></span></li><li><span><a href="#Вывести-на-экран-всю-информацию-о-людях,-у-которых-названия-аккаунтов-в-твиттере-содержат-подстроку-'money',-а-фамилия-начинается-на-'K'." data-toc-modified-id="Вывести-на-экран-всю-информацию-о-людях,-у-которых-названия-аккаунтов-в-твиттере-содержат-подстроку-'money',-а-фамилия-начинается-на-'K'.-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Вывести на экран всю информацию о людях, у которых названия аккаунтов в твиттере содержат подстроку 'money', а фамилия начинается на 'K'.</a></span></li><li><span><a href="#Для-каждой-страны-отобразить-общую-сумму-привлечённых-инвестиций,-которые-получили-компании,-зарегистрированные-в-этой-стране.-Страну,-в-которой-зарегистрирована-компания,-можно-определить-по-коду-страны.-Отсортировать-данные-по-убыванию-суммы." data-toc-modified-id="Для-каждой-страны-отобразить-общую-сумму-привлечённых-инвестиций,-которые-получили-компании,-зарегистрированные-в-этой-стране.-Страну,-в-которой-зарегистрирована-компания,-можно-определить-по-коду-страны.-Отсортировать-данные-по-убыванию-суммы.-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Для каждой страны отобразить общую сумму привлечённых инвестиций, которые получили компании, зарегистрированные в этой стране. Страну, в которой зарегистрирована компания, можно определить по коду страны. Отсортировать данные по убыванию суммы.</a></span></li><li><span><a href="#Составить-таблицу,-в-которую-войдёт-дата-проведения-раунда,-а-также-минимальное-и-максимальное-значения-суммы-инвестиций,-привлечённых-в-эту-дату.-В-итоговой-таблице-оставить-только-те-записи,-в-которых-минимальное-значение-суммы-инвестиций-не-равно-нулю-и-не-равно-максимальному-значению." data-toc-modified-id="Составить-таблицу,-в-которую-войдёт-дата-проведения-раунда,-а-также-минимальное-и-максимальное-значения-суммы-инвестиций,-привлечённых-в-эту-дату.-В-итоговой-таблице-оставить-только-те-записи,-в-которых-минимальное-значение-суммы-инвестиций-не-равно-нулю-и-не-равно-максимальному-значению.-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Составить таблицу, в которую войдёт дата проведения раунда, а также минимальное и максимальное значения суммы инвестиций, привлечённых в эту дату. В итоговой таблице оставить только те записи, в которых минимальное значение суммы инвестиций не равно нулю и не равно максимальному значению.</a></span></li><li><span><a href="#Создать-поле-с-категориями:" data-toc-modified-id="Создать-поле-с-категориями:-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Создать поле с категориями:</a></span></li><li><span><a href="#Для-каждой-из-категорий,-назначенных-в-предыдущем-задании,-посчитать-округлённое-до-ближайшего-целого-числа-среднее-количество-инвестиционных-раундов,-в-которых-фонд-принимал-участие.-Вывести-на-экран-категории-и-среднее-число-инвестиционных-раундов.-Отсортировать-таблицу-по-возрастанию-среднего." data-toc-modified-id="Для-каждой-из-категорий,-назначенных-в-предыдущем-задании,-посчитать-округлённое-до-ближайшего-целого-числа-среднее-количество-инвестиционных-раундов,-в-которых-фонд-принимал-участие.-Вывести-на-экран-категории-и-среднее-число-инвестиционных-раундов.-Отсортировать-таблицу-по-возрастанию-среднего.-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Для каждой из категорий, назначенных в предыдущем задании, посчитать округлённое до ближайшего целого числа среднее количество инвестиционных раундов, в которых фонд принимал участие. Вывести на экран категории и среднее число инвестиционных раундов. Отсортировать таблицу по возрастанию среднего.</a></span></li><li><span><a href="#Проанализировать,-в-каких-странах-находятся-фонды,-которые-чаще-всего-инвестируют-в-стартапы." data-toc-modified-id="Проанализировать,-в-каких-странах-находятся-фонды,-которые-чаще-всего-инвестируют-в-стартапы.-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Проанализировать, в каких странах находятся фонды, которые чаще всего инвестируют в стартапы.</a></span></li><li><span><a href="#Отобразить-имя-и-фамилию-всех-сотрудников-стартапов.-Добавить-поле-с-названием-учебного-заведения,-которое-окончил-сотрудник,-если-эта-информация-известна." data-toc-modified-id="Отобразить-имя-и-фамилию-всех-сотрудников-стартапов.-Добавить-поле-с-названием-учебного-заведения,-которое-окончил-сотрудник,-если-эта-информация-известна.-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Отобразить имя и фамилию всех сотрудников стартапов. Добавить поле с названием учебного заведения, которое окончил сотрудник, если эта информация известна.</a></span></li><li><span><a href="#Для-каждой-компании-найти-количество-учебных-заведений,-которые-окончили-её-сотрудники.-Вывести-название-компании-и-число-уникальных-названий-учебных-заведений.-Составить-топ-5-компаний-по-количеству-университетов." data-toc-modified-id="Для-каждой-компании-найти-количество-учебных-заведений,-которые-окончили-её-сотрудники.-Вывести-название-компании-и-число-уникальных-названий-учебных-заведений.-Составить-топ-5-компаний-по-количеству-университетов.-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Для каждой компании найти количество учебных заведений, которые окончили её сотрудники. Вывести название компании и число уникальных названий учебных заведений. Составить топ-5 компаний по количеству университетов.</a></span></li><li><span><a href="#Составить-список-с-уникальными-названиями-закрытых-компаний,-для-которых-первый-раунд-финансирования-оказался-последним." data-toc-modified-id="Составить-список-с-уникальными-названиями-закрытых-компаний,-для-которых-первый-раунд-финансирования-оказался-последним.-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Составить список с уникальными названиями закрытых компаний, для которых первый раунд финансирования оказался последним.</a></span></li><li><span><a href="#Составить-список-уникальных-номеров-сотрудников,-которые-работают-в-компаниях,-отобранных-в-предыдущем-задании." data-toc-modified-id="Составить-список-уникальных-номеров-сотрудников,-которые-работают-в-компаниях,-отобранных-в-предыдущем-задании.-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Составить список уникальных номеров сотрудников, которые работают в компаниях, отобранных в предыдущем задании.</a></span></li><li><span><a href="#Составить-таблицу,-куда-войдут-уникальные-пары-с-номерами-сотрудников-из-предыдущей-задачи-и-учебным-заведением,-которое-окончил-сотрудник." data-toc-modified-id="Составить-таблицу,-куда-войдут-уникальные-пары-с-номерами-сотрудников-из-предыдущей-задачи-и-учебным-заведением,-которое-окончил-сотрудник.-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Составить таблицу, куда войдут уникальные пары с номерами сотрудников из предыдущей задачи и учебным заведением, которое окончил сотрудник.</a></span></li><li><span><a href="#Посчитать-количество-учебных-заведений-для-каждого-сотрудника-из-предыдущего-задания.-При-подсчёте-учесть,-что-некоторые-сотрудники-могли-окончить-одно-и-то-же-заведение-дважды." data-toc-modified-id="Посчитать-количество-учебных-заведений-для-каждого-сотрудника-из-предыдущего-задания.-При-подсчёте-учесть,-что-некоторые-сотрудники-могли-окончить-одно-и-то-же-заведение-дважды.-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Посчитать количество учебных заведений для каждого сотрудника из предыдущего задания. При подсчёте учесть, что некоторые сотрудники могли окончить одно и то же заведение дважды.</a></span></li><li><span><a href="#Дополнить-предыдущий-запрос-и-вывести-среднее-число-учебных-заведений-(всех,-не-только-уникальных),-которые-окончили-сотрудники-разных-компаний.-Нужно-вывести-только-одну-запись,-группировка-здесь-не-понадобится." data-toc-modified-id="Дополнить-предыдущий-запрос-и-вывести-среднее-число-учебных-заведений-(всех,-не-только-уникальных),-которые-окончили-сотрудники-разных-компаний.-Нужно-вывести-только-одну-запись,-группировка-здесь-не-понадобится.-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>Дополнить предыдущий запрос и вывести среднее число учебных заведений (всех, не только уникальных), которые окончили сотрудники разных компаний. Нужно вывести только одну запись, группировка здесь не понадобится.</a></span></li><li><span><a href="#Написать-похожий-запрос:-выведите-среднее-число-учебных-заведений-(всех,-не-только-уникальных),-которые-окончили-сотрудники-Facebook." data-toc-modified-id="Написать-похожий-запрос:-выведите-среднее-число-учебных-заведений-(всех,-не-только-уникальных),-которые-окончили-сотрудники-Facebook.-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>Написать похожий запрос: выведите среднее число учебных заведений (всех, не только уникальных), которые окончили сотрудники Facebook.</a></span></li><li><span><a href="#Составить-таблицу-из-полей:" data-toc-modified-id="Составить-таблицу-из-полей:-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>Составить таблицу из полей:</a></span></li><li><span><a href="#Выгрузить-таблицу,-в-которой-будут-такие-поля:" data-toc-modified-id="Выгрузить-таблицу,-в-которой-будут-такие-поля:-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>Выгрузить таблицу, в которой будут такие поля:</a></span></li><li><span><a href="#Выгрузить-таблицу,-в-которую-войдут-названия-компаний-из-категории-social,-получившие-финансирование-с-2010-по-2013-год-включительно.-Проверить,-что-сумма-инвестиций-не-равна-нулю.-Вывести-также-номер-месяца,-в-котором-проходил-раунд-финансирования." data-toc-modified-id="Выгрузить-таблицу,-в-которую-войдут-названия-компаний-из-категории-social,-получившие-финансирование-с-2010-по-2013-год-включительно.-Проверить,-что-сумма-инвестиций-не-равна-нулю.-Вывести-также-номер-месяца,-в-котором-проходил-раунд-финансирования.-2.21"><span class="toc-item-num">2.21&nbsp;&nbsp;</span>Выгрузить таблицу, в которую войдут названия компаний из категории social, получившие финансирование с 2010 по 2013 год включительно. Проверить, что сумма инвестиций не равна нулю. Вывести также номер месяца, в котором проходил раунд финансирования.</a></span></li><li><span><a href="#Отобрать-данные-по-месяцам-с-2010-по-2013-год,-когда-проходили-инвестиционные-раунды.-Сгруппировать-данные-по-номеру-месяца-и-получите-таблицу,-в-которой-будут-поля:" data-toc-modified-id="Отобрать-данные-по-месяцам-с-2010-по-2013-год,-когда-проходили-инвестиционные-раунды.-Сгруппировать-данные-по-номеру-месяца-и-получите-таблицу,-в-которой-будут-поля:-2.22"><span class="toc-item-num">2.22&nbsp;&nbsp;</span>Отобрать данные по месяцам с 2010 по 2013 год, когда проходили инвестиционные раунды. Сгруппировать данные по номеру месяца и получите таблицу, в которой будут поля:</a></span></li><li><span><a href="#Составить-сводную-таблицу-и-вывести-среднюю-сумму-инвестиций-для-стран,-в-которых-есть-стартапы,-зарегистрированные-в-2011,-2012-и-2013-годах.-Данные-за-каждый-год-должны-быть-в-отдельном-поле.-Отсортировать-таблицу-по-среднему-значению-инвестиций-за-2011-год-от-большего-к-меньшему." data-toc-modified-id="Составить-сводную-таблицу-и-вывести-среднюю-сумму-инвестиций-для-стран,-в-которых-есть-стартапы,-зарегистрированные-в-2011,-2012-и-2013-годах.-Данные-за-каждый-год-должны-быть-в-отдельном-поле.-Отсортировать-таблицу-по-среднему-значению-инвестиций-за-2011-год-от-большего-к-меньшему.-2.23"><span class="toc-item-num">2.23&nbsp;&nbsp;</span>Составить сводную таблицу и вывести среднюю сумму инвестиций для стран, в которых есть стартапы, зарегистрированные в 2011, 2012 и 2013 годах. Данные за каждый год должны быть в отдельном поле. Отсортировать таблицу по среднему значению инвестиций за 2011 год от большего к меньшему.</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Задание
#
# Проанализировать данные о фондах и инвестициях и написать запросы к базе.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **acquisition**
#
# Содержит информацию о покупках одних компаний другими.
# * первичный ключ id — идентификатор или уникальный номер покупки;
# * внешний ключ acquiring_company_id — ссылается на таблицу company — идентификатор компании-покупателя, то есть той, что покупает другую компанию;
# * внешний ключ acquired_company_id — ссылается на таблицу company — идентификатор компании, которую покупают;
# * term_code — способ оплаты сделки:
# * cash — наличными;
# * stock — акциями компании;
# * cash_and_stock — смешанный тип оплаты: наличные и акции.
# * price_amount — сумма покупки в долларах;
# * acquired_at — дата совершения сделки;
# * created_at — дата и время создания записи в таблице;
# * updated_at — дата и время обновления записи в таблице.
#
# **company**
#
# Содержит информацию о компаниях-стартапах.
# * первичный ключ id — идентификатор, или уникальный номер компании;
# * name — название компании;
# * category_code — категория деятельности компании, например:
# * news — специализируется на работе с новостями;
# * social — специализируется на социальной работе.
# * status — статус компании:
# * acquired — приобретена;
# * operating — действует;
# * ipo — вышла на IPO;
# * closed — перестала существовать.
# * founded_at — дата основания компании;
# * closed_at — дата закрытия компании, которую указывают в том случае, если компании больше не существует;
# * domain — домен сайта компании;
# * twitter_username — название профиля компании в твиттере;
# * country_code — код страны, например, USA для США, GBR для Великобритании;
# * investment_rounds — число раундов, в которых компания участвовала как инвестор;
# * funding_rounds — число раундов, в которых компания привлекала инвестиции;
# * funding_total — сумма привлечённых инвестиций в долларах;
# * milestones — количество важных этапов в истории компании;
# * created_at — дата и время создания записи в таблице;
# * updated_at — дата и время обновления записи в таблице.
#
# **education**
#
# Хранит информацию об уровне образования сотрудников компаний.
# * первичный ключ id — уникальный номер записи с информацией об образовании;
# * внешний ключ person_id — ссылается на таблицу people — идентификатор человека, информация о котором представлена в записи;
# * degree_type — учебная степень, например:
# * BA — Bachelor of Arts — бакалавр гуманитарных наук;
# * MS — Master of Science — магистр естественных наук.
# * instituition — учебное заведение, название университета;
# * graduated_at — дата завершения обучения, выпуска;
# * created_at — дата и время создания записи в таблице;
# * updated_at — дата и время обновления записи в таблице.
#
# **fund**
#
# Хранит информацию о венчурных фондах.
# * первичный ключ id — уникальный номер венчурного фонда;
# * name — название венчурного фонда;
# * founded_at — дата основания фонда;
# * domain — домен сайта фонда;
# * twitter_username — профиль фонда в твиттере;
# * country_code — код страны фонда;
# * investment_rounds — число инвестиционных раундов, в которых фонд принимал участие;
# * invested_companies — число компаний, в которые инвестировал фонд;
# * milestones — количество важных этапов в истории фонда;
# * created_at — дата и время создания записи в таблице;
# * updated_at — дата и время обновления записи в таблице.
#
# **funding_round**
#
# Содержит информацию о раундах инвестиций.
# * первичный ключ id — уникальный номер инвестиционного раунда;
# * внешний ключ company_id — ссылается на таблицу company — уникальный номер компании, участвовавшей в инвестиционном раунде;
# * funded_at — дата проведения раунда;
# * funding_round_type — тип инвестиционного раунда, например:
# * venture — венчурный раунд;
# * angel — ангельский раунд;
# * series_a — раунд А.
# * raised_amount — сумма инвестиций, которую привлекла компания в этом раунде в долларах;
# * pre_money_valuation — предварительная, проведённая до инвестиций оценка стоимости компании в долларах;
# * participants — количество участников инвестиционного раунда;
# * is_first_round — является ли этот раунд первым для компании;
# * is_last_round — является ли этот раунд последним для компании;
# * created_at — дата и время создания записи в таблице;
# * updated_at — дата и время обновления записи в таблице.
#
# **investment**
#
# Содержит информацию об инвестициях венчурных фондов в компании-стартапы.
# * первичный ключ id — уникальный номер инвестиции;
# * внешний ключ funding_round_id — ссылается на таблицу funding_round — уникальный номер раунда инвестиции;
# * внешний ключ company_id — ссылается на таблицу company — уникальный номер компании-стартапа, в которую инвестируют;
# * внешний ключ fund_id — ссылается на таблицу fund — уникальный номер фонда, инвестирующего в компанию-стартап;
# * created_at — дата и время создания записи в таблице;
# * updated_at — дата и время обновления записи в таблице.
#
# **people**
#
# Содержит информацию о сотрудниках компаний-стартапов.
# * первичный ключ id — уникальный номер сотрудника;
# * first_name — имя сотрудника;
# * last_name — фамилия сотрудника;
# * внешний ключ company_id — ссылается на таблицу company — уникальный номер компании-стартапа;
# * twitter_username — профиль сотрудника в твиттере;
# * created_at — дата и время создания записи в таблице;
# * updated_at — дата и время обновления записи в таблице.

# %% [markdown]
# ## Запросы

# %% [markdown]
# ### Посчитать, сколько компаний закрылось.

# %%
SELECT count(id)
FROM company
WHERE status = 'closed'

# %% [markdown]
# ### Отобразить количество привлечённых средств для новостных компаний США. Отсортировать таблицу по убыванию значений в поле funding_total.

# %%
SELECT funding_total
FROM company
WHERE category_code = 'news'
  AND country_code = 'USA'
ORDER BY funding_total DESC

# %% [markdown]
# ### Найти общую сумму сделок по покупке одних компаний другими в долларах. Отобрать сделки, которые осуществлялись только за наличные с 2011 по 2013 год включительно.

# %%
SELECT sum(price_amount)
FROM acquisition
WHERE term_code = 'cash'
  AND extract(YEAR
              FROM CAST(acquired_at AS date)) BETWEEN 2011 AND 2013

# %% [markdown]
# ### Отобразить имя, фамилию и названия аккаунтов людей в твиттере, у которых названия аккаунтов начинаются на 'Silver'.

# %%
SELECT p.first_name,
       p.last_name,
       p.twitter_username
FROM people AS p
WHERE p.twitter_username like 'Silver%'

# %% [markdown]
# ### Вывести на экран всю информацию о людях, у которых названия аккаунтов в твиттере содержат подстроку 'money', а фамилия начинается на 'K'.

# %%
SELECT *
FROM people AS p
WHERE p.twitter_username like '%money%'
  AND p.last_name like 'K%'

# %% [markdown]
# ### Для каждой страны отобразить общую сумму привлечённых инвестиций, которые получили компании, зарегистрированные в этой стране. Страну, в которой зарегистрирована компания, можно определить по коду страны. Отсортировать данные по убыванию суммы.

# %%
SELECT country_code,
       sum(funding_total) AS total
FROM company
GROUP BY country_code
ORDER BY total DESC

# %% [markdown]
# ### Составить таблицу, в которую войдёт дата проведения раунда, а также минимальное и максимальное значения суммы инвестиций, привлечённых в эту дату. В итоговой таблице оставить только те записи, в которых минимальное значение суммы инвестиций не равно нулю и не равно максимальному значению.

# %%
SELECT funded_at AS date,
       min(raised_amount) AS MIN,
       max(raised_amount) AS MAX
FROM funding_round
GROUP BY date
HAVING min(raised_amount) > 0
AND min(raised_amount) <> max(raised_amount)

# %% [markdown]
# ### Создать поле с категориями:
# * Для фондов, которые инвестируют в 100 и более компаний, назначьте категорию high_activity.
# * Для фондов, которые инвестируют в 20 и более компаний до 100, назначьте категорию middle_activity.
# * Если количество инвестируемых компаний фонда не достигает 20, назначьте категорию low_activity.
# **Отобразить все поля таблицы fund и новое поле с категориями.*

# %%
SELECT *,
       CASE
           WHEN invested_companies >= 100 THEN 'high_activity'
           WHEN invested_companies < 100
                AND invested_companies >= 20 THEN 'middle_activity'
           WHEN invested_companies < 20 THEN 'low_activity'
       END
FROM fund AS f

# %% [markdown]
# ### Для каждой из категорий, назначенных в предыдущем задании, посчитать округлённое до ближайшего целого числа среднее количество инвестиционных раундов, в которых фонд принимал участие. Вывести на экран категории и среднее число инвестиционных раундов. Отсортировать таблицу по возрастанию среднего.

# %%
SELECT activity,
       round(avg(investment_rounds)) AS quantity
FROM
  (SELECT *,
          CASE
              WHEN invested_companies>=100 THEN 'high_activity'
              WHEN invested_companies>=20 THEN 'middle_activity'
              ELSE 'low_activity'
          END AS activity
   FROM fund) AS f
GROUP BY f.activity
ORDER BY quantity

# %% [markdown]
# ### Проанализировать, в каких странах находятся фонды, которые чаще всего инвестируют в стартапы.
# Для каждой страны посчитать минимальное, максимальное и среднее число компаний, в которые инвестировали фонды этой страны, основанные с 2010 по 2012 год включительно.
# Исключить страны с фондами, у которых минимальное число компаний, получивших инвестиции, равно нулю.
# Выгрузить десять самых активных стран-инвесторов: отсортировать таблицу по среднему количеству компаний от большего к меньшему. Затем добавьте сортировку по коду страны в лексикографическом порядке.

# %%
SELECT f.country_code AS country,
       min(invested_companies) AS minimum,
       max(invested_companies) AS maximum,
       avg(invested_companies) AS average
FROM fund AS f
WHERE extract(YEAR
              FROM cast(f.founded_at AS date)) BETWEEN 2010 AND 2012
GROUP BY country
HAVING min(invested_companies) > 0
ORDER BY average DESC,
         country
LIMIT 10

# %% [markdown]
# ### Отобразить имя и фамилию всех сотрудников стартапов. Добавить поле с названием учебного заведения, которое окончил сотрудник, если эта информация известна.

# %%
SELECT first_name,
       last_name,
       e.instituition
FROM people AS p
LEFT JOIN education AS e ON p.id = e.person_id

# %% [markdown]
# ### Для каждой компании найти количество учебных заведений, которые окончили её сотрудники. Вывести название компании и число уникальных названий учебных заведений. Составить топ-5 компаний по количеству университетов.

# %%
SELECT c.name AS company,
       count(DISTINCT e.instituition) AS insituition
FROM company AS c
JOIN people AS p ON c.id = p.company_id
JOIN education AS e ON p.id = e.person_id
GROUP BY company
ORDER BY insituition DESC
LIMIT 5

# %% [markdown]
# ### Составить список с уникальными названиями закрытых компаний, для которых первый раунд финансирования оказался последним.

# %%
SELECT DISTINCT name
FROM company AS c
JOIN funding_round AS fr ON c.id = fr.company_id
WHERE fr.id in
    (SELECT fr.id
     FROM funding_round AS fr
     WHERE fr.is_first_round = 1
       AND fr.is_last_round = 1)
  AND status = 'closed'

# %% [markdown]
# ### Составить список уникальных номеров сотрудников, которые работают в компаниях, отобранных в предыдущем задании.

# %%
SELECT DISTINCT p.id
FROM people AS p
WHERE p.company_id in
    (SELECT DISTINCT c.id
     FROM company AS c
     JOIN funding_round AS fr ON c.id = fr.company_id
     LEFT JOIN people AS p ON c.id = p.company_id
     WHERE fr.id in
         (SELECT fr.id
          FROM funding_round AS fr
          WHERE fr.is_first_round = 1
            AND fr.is_last_round = 1)
       AND status = 'closed')

# %% [markdown]
# ### Составить таблицу, куда войдут уникальные пары с номерами сотрудников из предыдущей задачи и учебным заведением, которое окончил сотрудник.

# %%
SELECT DISTINCT p.id,
                e.instituition
FROM people AS p
JOIN education AS e ON p.id = e.person_id
WHERE p.company_id in
    (SELECT DISTINCT c.id
     FROM company AS c
     JOIN funding_round AS fr ON c.id = fr.company_id
     LEFT JOIN people AS p ON c.id = p.company_id
     WHERE fr.id in
         (SELECT fr.id
          FROM funding_round AS fr
          WHERE fr.is_first_round = 1
            AND fr.is_last_round = 1)
       AND status = 'closed')

# %% [markdown]
# ### Посчитать количество учебных заведений для каждого сотрудника из предыдущего задания. При подсчёте учесть, что некоторые сотрудники могли окончить одно и то же заведение дважды.

# %%
SELECT DISTINCT p.id AS employee,
                count(e.instituition)
FROM people AS p
JOIN education AS e ON p.id = e.person_id
WHERE p.company_id in
    (SELECT DISTINCT c.id
     FROM company AS c
     JOIN funding_round AS fr ON c.id = fr.company_id
     LEFT JOIN people AS p ON c.id = p.company_id
     WHERE fr.id in
         (SELECT fr.id
          FROM funding_round AS fr
          WHERE fr.is_first_round = 1
            AND fr.is_last_round = 1)
       AND status = 'closed')
GROUP BY employee

# %% [markdown]
# ### Дополнить предыдущий запрос и вывести среднее число учебных заведений (всех, не только уникальных), которые окончили сотрудники разных компаний. Нужно вывести только одну запись, группировка здесь не понадобится.

# %%
SELECT avg(p.count)
FROM
  (SELECT DISTINCT p.id AS employee,
                   count(e.instituition) AS COUNT
   FROM people AS p
   JOIN education AS e ON p.id = e.person_id
   WHERE p.company_id in
       (SELECT DISTINCT c.id
        FROM company AS c
        JOIN funding_round AS fr ON c.id = fr.company_id
        LEFT JOIN people AS p ON c.id = p.company_id
        WHERE fr.id in
            (SELECT fr.id
             FROM funding_round AS fr
             WHERE fr.is_first_round = 1
               AND fr.is_last_round = 1)
          AND status = 'closed')
   GROUP BY employee) AS p

# %% [markdown]
# ### Написать похожий запрос: выведите среднее число учебных заведений (всех, не только уникальных), которые окончили сотрудники Facebook.

# %%
SELECT avg(l.count)
FROM
  (SELECT p.employee,
          count(p.instituition)
   FROM
     (SELECT p.id AS employee,
             e.id AS instituition
      FROM people AS p
      JOIN education AS e ON p.id = e.person_id
      WHERE company_id in
          (SELECT id
           FROM company
           WHERE name = 'Facebook')) AS p
   GROUP BY p.employee) AS l

# %% [markdown]
# ### Составить таблицу из полей:
# * name_of_fund — название фонда;
# * name_of_company — название компании;
# * amount — сумма инвестиций, которую привлекла компания в раунде.
#
# **В таблицу войдут данные о компаниях, в истории которых было больше шести важных этапов, а раунды финансирования проходили с 2012 по 2013 год включительно.**

# %%
SELECT f.name AS name_of_fund,
       c.name AS name_of_company,
       fr.raised_amount AS amount
FROM investment AS i
LEFT JOIN company AS c ON c.id = i.company_id
LEFT JOIN fund AS f ON f.id = i.fund_id
INNER JOIN
  (SELECT *
   FROM funding_round
   WHERE EXTRACT(YEAR
                 FROM funded_at) BETWEEN 2012 AND 2013) AS fr ON fr.id = i.funding_round_id
WHERE c.milestones > 6;

# %% [markdown]
# ### Выгрузить таблицу, в которой будут такие поля:
# * название компании-покупателя;
# * сумма сделки;
# * название компании, которую купили;
# * сумма инвестиций, вложенных в купленную компанию;
# * доля, которая отображает, во сколько раз сумма покупки превысила сумму вложенных в компанию инвестиций, округлённая до ближайшего целого числа.
#
# **Не учитывайте те сделки, в которых сумма покупки равна нулю. Если сумма инвестиций в компанию равна нулю, исключите такую компанию из таблицы.
# Отсортируйте таблицу по сумме сделки от большей к меньшей, а затем по названию купленной компании в лексикографическом порядке. Ограничьте таблицу первыми десятью записями.**

# %%
SELECT c1.name AS name1,
       price_amount,
       c2.name AS name2,
       c2.funding_total,
       round(price_amount / c2.funding_total)
FROM acquisition AS a
JOIN company AS c1 ON c1.id = a.acquiring_company_id
JOIN company AS c2 ON c2.id = a.acquired_company_id
WHERE c2.funding_total <> 0
  AND price_amount <>0
ORDER BY price_amount DESC,
         c2.name
LIMIT 10

# %% [markdown]
# ### Выгрузить таблицу, в которую войдут названия компаний из категории social, получившие финансирование с 2010 по 2013 год включительно. Проверить, что сумма инвестиций не равна нулю. Вывести также номер месяца, в котором проходил раунд финансирования.

# %%
SELECT c.name,
       extract(MONTH
               FROM cast(fr.funded_at AS date))
FROM company c
JOIN funding_round AS fr ON c.id = fr.company_id
WHERE category_code = 'social'
  AND extract(YEAR
              FROM cast(fr.funded_at AS date)) BETWEEN 2010 AND 2013
  AND raised_amount <> 0

# %% [markdown]
# ### Отобрать данные по месяцам с 2010 по 2013 год, когда проходили инвестиционные раунды. Сгруппировать данные по номеру месяца и получите таблицу, в которой будут поля:
# * номер месяца, в котором проходили раунды;
# * количество уникальных названий фондов из США, которые инвестировали в этом месяце;
# * количество компаний, купленных за этот месяц;
# * общая сумма сделок по покупкам в этом месяце.

# %%
WITH fund_info AS
  (SELECT extract(MONTH
                  FROM fr.funded_at) AS fund_month,
          count(DISTINCT f.name) AS fund_count
   FROM funding_round AS fr
   LEFT JOIN investment AS i ON fr.id = i.funding_round_id
   LEFT JOIN fund AS f ON i.fund_id = f.id
   WHERE fr.funded_at BETWEEN '2010-01-01' AND '2013-12-31'
     AND f.country_code='USA'
   GROUP BY fund_month),
     acquired_company AS
  (SELECT extract(MONTH
                  FROM ac.acquired_at) AS acq_month,
          count(ac.acquired_company_id) AS acquired_company,
          sum(ac.price_amount) AS sum_acquired
   FROM acquisition AS ac
   WHERE ac.acquired_at BETWEEN '2010-01-01' AND '2013-12-31'
   GROUP BY acq_month)
SELECT fund_month,
       fund_count,
       acquired_company,
       sum_acquired
FROM fund_info AS fi
LEFT JOIN acquired_company AS acq ON fi.fund_month = acq.acq_month

# %% [markdown]
# ### Составить сводную таблицу и вывести среднюю сумму инвестиций для стран, в которых есть стартапы, зарегистрированные в 2011, 2012 и 2013 годах. Данные за каждый год должны быть в отдельном поле. Отсортировать таблицу по среднему значению инвестиций за 2011 год от большего к меньшему.

# %%
WITH company_2011 AS
  (SELECT c2011.country_code,
          avg(c2011.funding_total) AS funding_2011
   FROM company AS c2011
   WHERE founded_at BETWEEN '2011-01-01' AND '2011-12-31'
   GROUP BY c2011.country_code),
     company_2012 AS
  (SELECT c2012.country_code,
          avg(c2012.funding_total) AS funding_2012
   FROM company AS c2012
   WHERE founded_at BETWEEN '2012-01-01' AND '2012-12-31'
   GROUP BY c2012.country_code),
     company_2013 AS
  (SELECT c2013.country_code AS cc2013,
          avg(c2013.funding_total) AS funding_2013
   FROM company AS c2013
   WHERE founded_at BETWEEN '2013-01-01' AND '2013-12-31'
   GROUP BY c2013.country_code)
SELECT cc2013,
       funding_2011,
       funding_2012,
       funding_2013
FROM company_2011 AS c11
JOIN company_2012 c12 ON c11.country_code = c12.country_code
JOIN company_2013 AS c13 ON c11.country_code = c13.cc2013
ORDER BY funding_2011 DESC
